# %%
import numpy

# %%
# Define a couple of variabiles
a = 3 # this is an "int"
b = 2.1 # this is a "float"
s = "Hello, World!" # this is a "str"
c = True # this is a "bool"

print(type(a))
print(type(s))

# %%
pi = 3.1415729327329032
print(f"the value of pi is: {pi:0.4f}")
# Out:
# the value of pi is: 3.1416

# %%
# Create a tuple
t = (1, True, "Hello")
print(t)
print(type(t))
# Tuple are not dinamic, are immutable
# t[0] = 2 ERROR

# And a List
# List can have different types
l = [2.3, 1, 0, -2]
print(l)
print(type(l))
print(type(l[0]), type(l[1]))
# Out:
# (1, True, 'Hello')
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 print(type(t))
#       5 # Tuple are not dinamic, are immutable
# ----> 6 t[0] = 2
#       8 # And a List
#       9 # List can have different types
#      10 l = [2.3, 1, 0, -2]
#
# TypeError: 'tuple' object does not support item assignment
